# %%
from src.noise import generate_signal, add_gaussian_noise

import matplotlib.pyplot as plt

signal = generate_signal()
noisy_signal = add_gaussian_noise(signal)

plt.plot(signal, label="clean")
plt.plot(noisy_signal, label="noisy")
plt.legend()

plt.savefig("../figures/noise_comparison.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent))
